# %% [markdown]
# <a href="https://colab.research.google.com/github/Aya122221/my-fisrt-repository/blob/Data-Driven-Predictions-A-Machine-Learning-Approach/Aya_Ibrahim1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('heart.csv')

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df.shape
# Out:
# (303, 14)

# %%
df.size
# Out:
# 4242

# %%
df.shape[0]
# Out:
# 303

# %%
len(df)
# Out:
# 303

# %%
len(df.columns)
# Out:
# 14

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df['age'].head(10)
# Out:
# 0    63
# 1    37
# 2    41
# 3    56
# 4    57
# 5    57
# 6    56
# 7    44
# 8    52
# 9    57
# Name: age, dtype: int64

# %%
df.loc[:4 , 'age']
# Out:
# 0    63
# 1    37
# 2    41
# 3    56
# 4    57
# Name: age, dtype: int64

# %%
df.iloc[:5 , 0]
# Out:
# 0    63
# 1    37
# 2    41
# 3    56
# 4    57
# Name: age, dtype: int64

# %%
df[['age' , 'target' , 'fbs']]
# Out:
#      age  target  fbs
# 0     63       1    1
# 1     37       1    0
# 2     41       1    0
# 3     56       1    0
# 4     57       1    0
# ..   ...     ...  ...
# 298   57       0    0
# 299   45       0    0
# 300   68       0    1
# 301   57       0    0
# 302   57       0    0
#
# [303 rows x 3 columns]

# %%
df.loc[20:30 , ['age' , 'target' , 'fbs']]
# Out:
#     age  target  fbs
# 20   59       1    0
# 21   44       1    0
# 22   42       1    0
# 23   61       1    1
# 24   40       1    0
# 25   71       1    0
# 26   59       1    1
# 27   51       1    0
# 28   65       1    1
# 29   53       1    1
# 30   41       1    0

# %%
df.iloc[20:31 , [0 , 13 , 5]]
# Out:
#     age  target  fbs
# 20   59       1    0
# 21   44       1    0
# 22   42       1    0
# 23   61       1    1
# 24   40       1    0
# 25   71       1    0
# 26   59       1    1
# 27   51       1    0
# 28   65       1    1
# 29   53       1    1
# 30   41       1    0

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
# Section 4
# Exercise:
# 1- Using  heart.csv file work with only the womens  in the data and
# 2-classify them to  patient with heart attack and healty person
# 3-(percentage)
import pandas as pd
df = pd.read_csv('heart.csv')
df[df['sex'] == 0]['target'].value_counts() / len(df[df['sex'] == 0])
# Out:
# target
# 1    0.75
# 0    0.25
# Name: count, dtype: float64

# %%
df['gender'] = df['sex'].map(lambda x: 'female' if x==0 else 'male')

# %%
df['attack'] = df['target'].map(lambda x: 'yes' if x == 1 else 'no')

# %%
pd.crosstab(df.gender , df.attack)
# Out:
# attack   no  yes
# gender
# female   24   72
# male    114   93

# %%
pd.crosstab(df.gender , df.attack , margins = True)
# Out:
# attack   no  yes  All
# gender
# female   24   72   96
# male    114   93  207
# All     138  165  303

# %%
pd.crosstab(df.gender , df.attack ).plot(kind = 'bar')
# Out:
# <Axes: xlabel='gender'>

# %%
df_temp = df[['age' , 'target']][0:9]
df_temp
# Out:
#    age  target
# 0   63       1
# 1   37       1
# 2   41       1
# 3   56       1
# 4   57       1
# 5   57       1
# 6   56       1
# 7   44       1
# 8   52       1

# %%
df.rename (columns = {'target':"heart_attack"} , inplace = True)

# %%
df_2 = df.transpose()

# %%
df2 = df_temp[['age', 'target']][3:]
df2
# Out:
#    age  target
# 3   56       1
# 4   57       1
# 5   57       1
# 6   56       1
# 7   44       1
# 8   52       1

# %%
df_temp = df[['age','heart_attack']][0:11]
df1 = df_temp[['age' ,  'heart_attack']][0:5]
df2 = df_temp[['age' , 'heart_attack']][10:11]
df_append = pd.concat([df1 , df2])
df_append
# Out:
#     age  heart_attack
# 0    63             1
# 1    37             1
# 2    41             1
# 3    56             1
# 4    57             1
# 10   54             1

# %%
df['chestPain3'] = df['cp'].replace({0:'typical angina', 1:'atypical angina', 2:'non-anginal pain', 3:'asymptomatic'})
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  heart_attack  gender attack        chestPain3
# ...

# %%
df22 = pd.read_csv('cancer_data.csv')
df22
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99           NaN          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
import matplotlib as pyplot
import numpy as np
# %matplotlib inline
